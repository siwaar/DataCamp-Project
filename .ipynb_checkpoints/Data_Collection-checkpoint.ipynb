# %% [markdown]
# <img src="saclay_center.png" width="800" height="600">

# %% [markdown]
# ### Datacamp Challenge : Prediction of daily transport validation in Paris public underground transports

# %% [markdown]
# <i> Authors : Siwar ABBES, Dina ABED, Philippe DE SAINT CHAMAS, Mohamed Skander HELLAL, Gwendal HENGOAT, Jules ZACCARDI </i>

# %% [markdown]
# ## Data Collection

# %% [markdown]
# ### Introduction

# %% [markdown]
# The Basic data used are in our challenge are the open data available on the Ile-de-France Mobilités platform which provides validation data of the entire Ile-de-France network. The transport network seen by the validation data covers 725 train stops (RER, metro, Transilien).
# Source: https://data.iledefrance-mobilites.fr/explore/dataset/histo-validations/information/
#
# We have merged all the data available since the first semester of 2015 until 2019. To get a whole observations of the number of validations per day and per stop.
#
# Thinking about some informations that could impact the frequentation of stations, our brainstorming leads to try to find other databases that contain these significant features to our business model:
#
# - find to which metro/RER line corresponds each stop, Database exploited: https://data.iledefrance-mobilites.fr/explore/dataset/emplacement-des-gares-idf-data-generalisee/information/
# - Search for a database of public holidays (whether public holiday or not and if so, the type of this day: Weekend, Christmas, Toussaint,...), Database exploited: https://www.data.gouv.fr/fr/datasets/jours-feries-en-france/
# - Incident rate, incident data on all RATP lines per day, Database exploited: http://data.cquest.org/openeventdatabase/
# - Social movements, Data on SNCF social movements: https://ressources.data.sncf.com/explore/dataset/mouvements-sociaux-depuis-2002/table/?sort=date_de_debut
# - Referential of passenger stations, Database: https://data.sncf.com/explore/dataset/frequentation-gares/table/?sort=nom_gare
#
# In order to get the data for the challenge, we worked on engineering features from the different databases defined above and merging them into a challenge data csv file

# %% [markdown]
# ### Importing the Libraries

# %%
import sys
import numpy as np
import pandas as pd 
from datetime import timedelta, date

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style('ticks')
sns.set(rc={'figure.figsize':(13.7,9.27)})
import warnings
warnings.filterwarnings('ignore')
import os
import folium
import pandas as pd
from IPython.display import display
from folium import Popup
import calendar
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### 1 .  Data of transport validation (Nombre de validations de Transport par jour)

# %%
allfiles = os.listdir('./data/data valid/')
li = []

for file in allfiles : 
    print(file)
    file = './data/data valid/' + file 
    if file[-3:] == 'csv':
        data = pd.read_csv(file, header=0, sep=';')
        data['JOUR'] = pd.to_datetime(data['JOUR'])
        li.append(data)
    else:
        data = pd.read_csv(file, header=0, sep='\t')
        data['JOUR'] = pd.to_datetime(data['JOUR'])
        li.append(data)

dt = pd.concat(li, axis=0, ignore_index=True)
# Out:
# 2015S2_NB_FER.csv
# 2018S1_NB_FER.txt
# 2017S2_NB_FER.txt
# 2016S2_NB_FER.txt
# validations-sur-le-reseau-ferre-nombre-de-validations-par-jour-1er-semestre-2019.csv
# 2016S1_NB_FER.txt
# 2017S1_NB_FER.txt
# 2015S1_NB_FER.csv

# %%
dt.head()
# Out:
#         JOUR  CODE_STIF_TRNS CODE_STIF_RES CODE_STIF_ARRET  LIBELLE_ARRET  \
# 0 2015-01-07             100           110               1  PORTE MAILLOT
# 1 2015-01-07             100           110               1  PORTE MAILLOT
# 2 2015-01-07             100           110               1  PORTE MAILLOT
# 3 2015-01-07             100           110               1  PORTE MAILLOT
# 4 2015-01-07             100           110               1  PORTE MAILLOT
#
#   ID_REFA_LDA CATEGORIE_TITRE NB_VALD
# 0       71379       AMETHYSTE     241
# 1       71379     AUTRE TITRE     215
# 2       71379             FGT     518
# 3       71379       IMAGINE R    2556
# 4       71379          NAVIGO   14463

# %%
dt.nunique()
# Out:
# JOUR                1458
# CODE_STIF_TRNS         3
# CODE_STIF_RES         15
# CODE_STIF_ARRET      757
# LIBELLE_ARRET        735
# ID_REFA_LDA         1390
# CATEGORIE_TITRE        9
# NB_VALD            53859
# dtype: int64

# %% [markdown]
# ### Target : NB_Valid  (Nombre de validations de Transport par jour)

# %%
(dt.loc[dt['NB_VALD'] == 'Moins de 5'].shape[0]/dt.shape[0])*100
# Out:
# 9.450435321932229

# %%
dt.loc[dt['NB_VALD'] == 'Moins de 5', 'NB_VALD'] = 5
dt['NB_VALD'] = pd.to_numeric(dt['NB_VALD'])

# %%
#dt['JOUR'] = dt['JOUR'].astype(str)

# %%
dt.dtypes
# Out:
# JOUR               datetime64[ns]
# CODE_STIF_TRNS              int64
# CODE_STIF_RES              object
# CODE_STIF_ARRET            object
# LIBELLE_ARRET              object
# ID_REFA_LDA                object
# CATEGORIE_TITRE            object
# NB_VALD                     int64
# dtype: object

# %%
dt_agg = pd.DataFrame(dt.groupby(["JOUR","LIBELLE_ARRET"])['NB_VALD'].sum().reset_index())

# %%
dt_agg.groupby('JOUR').sum().plot(figsize=(12,8))
plt.show()

# %%
dt_agg.head()
# Out:
#         JOUR                 LIBELLE_ARRET  NB_VALD
# 0 2015-01-01                      ABBESSES      750
# 1 2015-01-01                         ABLON      118
# 2 2015-01-01         ACHERES-GRAND-CORMIER       18
# 3 2015-01-01                 ACHERES-VILLE      482
# 4 2015-01-01  AEROPORT CHARLES DE GAULLE 1     1257

# %%
dt_agg.shape
# Out:
# (1026018, 3)

# %%
dt_agg.to_csv('./data/validation_data_agg_2015_2019.csv')

# %% [markdown]
# ### 2 . Positions Data (Positions geographiques des stations du reseau ratp)

# %%
pos = pd.read_csv("data/positions-geographiques-des-stations-du-reseau-ratp.csv", sep=';')
dt2 = pos[['Name','Coordinates']].copy()

l = np.array(dt2["Coordinates"].str.split(",").tolist())
dt2["lon"] = l[:,0]
dt2["lat"] = l[:,1]
dt2.drop("Coordinates",axis=1, inplace=True)

dt2['Name'] = dt2['Name'].str.lower()
dt2['Name'] = dt2['Name'].str.replace('[^\w]','')
dt2['Name'] = dt2['Name'].str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8')

dt2['lon'] = pd.to_numeric(dt2["lon"])
dt2['lat'] = pd.to_numeric(dt2["lat"])

dt2 = dt2.groupby('Name').mean().reset_index()
dt2.drop_duplicates(inplace=True)

dt2.head()
# Out:
#                               Name        lon       lat
# 0                       11novembre  48.849993  2.395659
# 1                   11novembre1918  48.824212  2.516243
# 2  11novembrecourcellesuryvetterer  48.700031  2.099321
# 3                    12fevrier1934  48.817827  2.308055
# 4                    17octobre1961  48.898062  2.216702

# %%
dt_agg['Name'] = dt_agg['LIBELLE_ARRET'].str.lower()
dt_agg['Name'] = dt_agg['Name'].str.replace('[^\w]','')
dt_agg['Name'] = dt_agg['Name'].str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8')

# %%
dt_agg_pos = dt_agg.merge(dt2, how='left', on='Name')
dt_agg_pos.drop('Name',axis=1,inplace=True)
dt_agg_pos.head()
# Out:
#         JOUR                 LIBELLE_ARRET  NB_VALD        lon       lat
# 0 2015-01-01                      ABBESSES      750  48.884505  2.338365
# 1 2015-01-01                         ABLON      118        NaN       NaN
# 2 2015-01-01         ACHERES-GRAND-CORMIER       18  48.955388  2.092457
# 3 2015-01-01                 ACHERES-VILLE      482  48.970248  2.077672
# 4 2015-01-01  AEROPORT CHARLES DE GAULLE 1     1257  49.010400  2.561357

# %% [markdown]
# ### 3 . Stations Data (Stations et types des moyens de transport correspondants)

# %%
gare_desc = pd.read_csv('data/emplacement-des-gares-idf-data-generalisee.csv',delimiter = ';')
stations_desc = pd.read_csv('data/stations.csv',delimiter = ';')
gare_desc = gare_desc[['nom_long','res_com','mode_','principal']]

# %%
dt_agg_pos = pd.merge(dt_agg_pos,gare_desc,left_on='LIBELLE_ARRET',right_on='nom_long',how = 'left') 
dt_agg_pos = dt_agg_pos.drop(columns = ['nom_long'],axis = 1)

# %%
gare_desc.head()
# Out:
#               nom_long  res_com    mode_  principal
# 0      REUILLY-DIDEROT  M1 / M8    Metro          0
# 1        LOUVRE-RIVOLI       M1    Metro          0
# 2           LES MILONS       T2  Tramway          0
# 3  LYCEE HENRI SELLIER       T4  Tramway          0
# 4           PARMENTIER       M3    Metro          0

# %%
gare_desc[gare_desc['nom_long'].str.contains("NATION")]
# Out:
#                 nom_long                    res_com        mode_  principal
# 419            NATIONALE                         M6        Metro          0
# 522               NATION  RER A / M1 / M2 / M6 / M9  RER / Metro          0
# 573  ASSEMBLEE NATIONALE                        M12        Metro          0

# %% [markdown]
# ### 4 . Correspondences  Data (Nombre de métro/ RER passant par une station)

# %%
corr = pd.read_csv('data/correspondances.csv')
corr['Name'] = corr['stop_name'].str.lower()
corr['Name'] = corr['Name'].str.replace('[^\w]','')
corr['Name'] = corr['Name'].str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8')

dt_agg_pos['Name'] = dt_agg_pos['LIBELLE_ARRET'].str.lower()
dt_agg_pos['Name'] = dt_agg_pos['Name'].str.replace('[^\w]','')
dt_agg_pos['Name'] = dt_agg_pos['Name'].str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8')

dt_agg_pos_corr = dt_agg_pos.merge(corr, how='left', on='Name')
dt_agg_pos_corr.drop(['Name','stop_name'],axis=1,inplace=True)
dt_agg_pos_corr.head()
# Out:
#         JOUR                 LIBELLE_ARRET  NB_VALD        lon       lat  \
# 0 2015-01-01                      ABBESSES      750  48.884505  2.338365
# 1 2015-01-01                         ABLON      118        NaN       NaN
# 2 2015-01-01         ACHERES-GRAND-CORMIER       18  48.955388  2.092457
# 3 2015-01-01                 ACHERES-VILLE      482  48.970248  2.077672
# 4 2015-01-01  AEROPORT CHARLES DE GAULLE 1     1257  49.010400  2.561357
#
#            res_com          mode_  principal  nb_metro  nb_rer line
# 0              M12          Metro        0.0       1.0     0.0   12
# 1            RER C            RER        0.0       0.0     1.0  NaN
# 2            RER A            RER        0.0       0.0     1.0  NaN
# 3  LIGNE L / RER A    Train / RER        0.0       0.0     1.0  NaN
# 4   RER B / CDGVAL  RER / Navette        0.0       0.0     1.0  NaN

# %% [markdown]
# ### 5 . Stations Repository Data (Réferentiel gares voyageurs)

# %%
ref = pd.read_csv('data/referentiel-gares-voyageurs.csv',delimiter = ';')
ref  = ref[['Intitulé gare','Segment DRG','Nbre plateformes']]
ref['Intitulé gare'] = ref['Intitulé gare'].apply(lambda x : x.upper())

# %%
dt_agg_pos_corr = pd.merge(dt_agg_pos_corr,ref,left_on='LIBELLE_ARRET',right_on='Intitulé gare',how = 'left') 
dt_agg_pos_corr = dt_agg_pos_corr.drop(columns = ['Intitulé gare'],axis=1)

# %%
dt_agg_pos_corr.head()
# Out:
#         JOUR                 LIBELLE_ARRET  NB_VALD        lon       lat  \
# 0 2015-01-01                      ABBESSES      750  48.884505  2.338365
# 1 2015-01-01                         ABLON      118        NaN       NaN
# 2 2015-01-01         ACHERES-GRAND-CORMIER       18  48.955388  2.092457
# 3 2015-01-01                 ACHERES-VILLE      482  48.970248  2.077672
# 4 2015-01-01  AEROPORT CHARLES DE GAULLE 1     1257  49.010400  2.561357
#
#            res_com          mode_  principal  nb_metro  nb_rer line  \
# 0              M12          Metro        0.0       1.0     0.0   12
# 1            RER C            RER        0.0       0.0     1.0  NaN
# 2            RER A            RER        0.0       0.0     1.0  NaN
# 3  LIGNE L / RER A    Train / RER        0.0       0.0     1.0  NaN
# 4   RER B / CDGVAL  RER / Navette        0.0       0.0     1.0  NaN
#
#   Segment DRG  Nbre plateformes
# 0         NaN               NaN
# 1           b               1.0
# 2         NaN               NaN
# 3         NaN               NaN
# 4         NaN               NaN

# %% [markdown]
# ### 6 . Incidents Data

# %%
inc = pd.read_csv('./data/incidents_2016_2019_clean.csv')
inc['day'] = inc['date'].str[:10]
inc['duree'] = pd.to_timedelta(inc['duree'])
inc.head()
# Out:
#      duree                 date line_num line_type                what  \
# 0 00:00:00  2016-07-01 10:34:00       12     metro          pedestrian
# 1 00:00:00  2016-07-01 10:42:00       12     metro          pedestrian
# 2 00:00:00  2016-07-01 11:30:00       12     metro          pedestrian
# 3 00:37:00  2016-07-01 12:57:00        6     metro  unattended_luggage
# 4 00:10:00  2016-07-01 13:35:00        6     metro  unattended_luggage
#
#       type_inc         day
# 0  unscheduled  2016-07-01
# 1  unscheduled  2016-07-01
# 2  unscheduled  2016-07-01
# 3  unscheduled  2016-07-01
# 4  unscheduled  2016-07-01

# %%
inc_group = inc.groupby(['day','line_num']).agg({
    'duree' : sum,
    'what' : 'first',
    'type_inc' : 'count'
}).reset_index().rename(columns={'type_inc':'num_inc','what':'type_inc'})
inc_group['day'] = pd.to_datetime(inc_group['day'])

inc_group.head()
# Out:
#          day line_num    duree   type_inc  num_inc
# 0 2016-05-01        1 00:00:00    generic        2
# 1 2016-05-01       11 00:00:00      smoke        1
# 2 2016-05-01       13 00:26:00  breakdown        4
# 3 2016-05-01        2 00:00:00  breakdown        3
# 4 2016-05-01        7 00:00:00  breakdown        2

# %%
inc_station = inc_group.merge(corr, how='left',left_on='line_num',right_on='line').drop(['line','Name','nb_metro','nb_rer'],axis=1)

inc_station.head()
# Out:
#          day line_num  duree type_inc  num_inc        stop_name
# 0 2016-05-01        1 0 days  generic        2  REUILLY-DIDEROT
# 1 2016-05-01        1 0 days  generic        2    LOUVRE-RIVOLI
# 2 2016-05-01        1 0 days  generic        2         CONCORDE
# 3 2016-05-01        1 0 days  generic        2         GEORGE V
# 4 2016-05-01        1 0 days  generic        2        ARGENTINE

# %%
dt_agg_pos_corr.head()
# Out:
#         JOUR                 LIBELLE_ARRET  NB_VALD        lon       lat  \
# 0 2015-01-01                      ABBESSES      750  48.884505  2.338365
# 1 2015-01-01                         ABLON      118        NaN       NaN
# 2 2015-01-01         ACHERES-GRAND-CORMIER       18  48.955388  2.092457
# 3 2015-01-01                 ACHERES-VILLE      482  48.970248  2.077672
# 4 2015-01-01  AEROPORT CHARLES DE GAULLE 1     1257  49.010400  2.561357
#
#            res_com          mode_  principal  nb_metro  nb_rer line  \
# 0              M12          Metro        0.0       1.0     0.0   12
# 1            RER C            RER        0.0       0.0     1.0  NaN
# 2            RER A            RER        0.0       0.0     1.0  NaN
# 3  LIGNE L / RER A    Train / RER        0.0       0.0     1.0  NaN
# 4   RER B / CDGVAL  RER / Navette        0.0       0.0     1.0  NaN
#
#   Segment DRG  Nbre plateformes
# 0         NaN               NaN
# 1           b               1.0
# 2         NaN               NaN
# 3         NaN               NaN
# 4         NaN               NaN

# %%
inc_station['Name'] = inc_station['stop_name'].str.lower()
inc_station['Name'] = inc_station['Name'].str.replace('[^\w]','')
inc_station['Name'] = inc_station['Name'].str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8')

inc_station['day'] = inc_station['day'].astype(str)

curr_dt = dt_agg_pos_corr.copy()

curr_dt['Name'] = curr_dt['LIBELLE_ARRET'].str.lower()
curr_dt['Name'] = curr_dt['Name'].str.replace('[^\w]','')
curr_dt['Name'] = curr_dt['Name'].str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8')

curr_dt['JOUR'] = curr_dt['JOUR'].astype(str)

# %%
dt_pos_cor_inc = curr_dt.merge(inc_station, how='left',left_on=['JOUR','Name'], right_on=['day','Name'])
dt_pos_cor_inc.drop(['Name','day','line_num','stop_name'],axis=1,inplace=True)

dt_pos_cor_inc.head()
# Out:
#          JOUR                 LIBELLE_ARRET  NB_VALD        lon       lat  \
# 0  2015-01-01                      ABBESSES      750  48.884505  2.338365
# 1  2015-01-01                         ABLON      118        NaN       NaN
# 2  2015-01-01         ACHERES-GRAND-CORMIER       18  48.955388  2.092457
# 3  2015-01-01                 ACHERES-VILLE      482  48.970248  2.077672
# 4  2015-01-01  AEROPORT CHARLES DE GAULLE 1     1257  49.010400  2.561357
#
#            res_com          mode_  principal  nb_metro  nb_rer line  \
# 0              M12          Metro        0.0       1.0     0.0   12
# 1            RER C            RER        0.0       0.0     1.0  NaN
# 2            RER A            RER        0.0       0.0     1.0  NaN
# 3  LIGNE L / RER A    Train / RER        0.0       0.0     1.0  NaN
# 4   RER B / CDGVAL  RER / Navette        0.0       0.0     1.0  NaN
#
#   Segment DRG  Nbre plateformes duree type_inc  num_inc
# 0         NaN               NaN   NaT      NaN      NaN
# 1           b               1.0   NaT      NaN      NaN
# 2         NaN               NaN   NaT      NaN      NaN
# 3         NaN               NaN   NaT      NaN      NaN
# 4         NaN               NaN   NaT      NaN      NaN

# %%
dt_pos_cor_inc.loc[dt_pos_cor_inc['num_inc'].notna()].head()
# Out:
#               JOUR    LIBELLE_ARRET  NB_VALD        lon       lat   res_com  \
# 375032  2016-05-01  ALEXANDRE DUMAS    10584  48.872031  2.416374        M2
# 375039  2016-05-01           ANVERS     9382  48.882872  2.344164        M2
# 375042  2016-05-01        ARGENTINE     8038  48.875693  2.289097        M1
# 375058  2016-05-01            AVRON     5099  48.850355  2.465669        M2
# 375061  2016-05-01           BALARD    13411  48.836384  2.278305  M8 / T3A
#
#                   mode_  principal  nb_metro  nb_rer line Segment DRG  \
# 375032            Metro        0.0       1.0     0.0    2         NaN
# 375039            Metro        0.0       1.0     0.0    2         NaN
# 375042            Metro        0.0       1.0     0.0    1         NaN
# 375058            Metro        0.0       1.0     0.0    2         NaN
# 375061  Metro / Tramway        0.0       1.0     0.0    8         NaN
#
#         Nbre plateformes    duree   type_inc  num_inc
# 375032               NaN 00:00:00  breakdown      3.0
# 375039               NaN 00:00:00  breakdown      3.0
# 375042               NaN 00:00:00    generic      2.0
# 375058               NaN 00:00:00  breakdown      3.0
# 375061               NaN 01:55:00  breakdown      5.0

# %% [markdown]
# ### 7 . Social movements Data ( Mouvements sociaux)

# %%
mvs = pd.read_csv('data/mouvements-sociaux.csv',delimiter=';')
mvs.head()
# Out:
#   date_de_debut date_de_fin  \
# 0    2002-10-02  2002-10-04
# 1    2003-05-25         NaN
# 2    2003-06-10  2003-06-11
# 3    2003-06-10         NaN
# 4    2003-12-16  2003-12-18
#
#                                        Motif exprimé Organisations syndicales  \
# 0  Manifestation nationale pour la défense du ser...              SUD;CFDT;FO
# 1                                         Retraites.          CGT;SUD;CFDT;FO
# 2                             Retraites et salaires.                     UNSA
# 3                                         Retraites.                       FO
# 4            Fret, emploi, salaires, droit de grève.                  CGT;SUD
#
#                        Métiers ciblés par le préavis  \
# 0  conducteur;agent de manoeuvre;chef de bord;acc...
# 1  conducteur;agent de manoeuvre;chef de bord;acc...
# 2  conducteur;agent de manoeuvre;chef de bord;acc...
# 3                                 agent de manoeuvre
# 4  conducteur;agent de manoeuvre;chef de bord;acc...
#
#    Population devant travailler ciblee par le préavis  \
# 0                                            35643.0
# 1                                              557.0
# 2                                           119241.0
# 3                                            11090.0
# 4                                            27583.0
#
#    Nombre de grévistes du préavis  \
# 0                           267.0
# 1                            23.0
# 2                         37086.0
# 3                           358.0
# 4                          1036.0
#
#    Taux de grévistes au sein de la population concernée par le préavis
# 0                                                0.7
# 1                                                4.1
# 2                                               31.1
# 3                                                3.2
# 4                                                3.8

# %%
mvs['date_de_debut'] = pd.to_datetime(mvs['date_de_debut'],format="%Y/%m/%d")
mvs['date_de_fin'] = pd.to_datetime(mvs['date_de_fin'],format="%Y/%m/%d")
mvs  = mvs[mvs['date_de_debut'].isin(pd.date_range(start='20150101', end='20190630'))]
mvs_dates = mvs[['date_de_debut','date_de_fin']]

# %%
list_dates = []
for index in mvs_dates.index:
    start_date = mvs_dates['date_de_debut'][index]
    if  not pd.isna(mvs_dates['date_de_fin'][index]): 
        end_date = mvs_dates['date_de_fin'][index]
        for n in range(int ((end_date - start_date).days)):
            list_dates.append(start_date + timedelta(n))
    else : 
        list_dates.append(start_date)

# %%
mvs_dates = {'date': list_dates}
mvs_dates = pd.DataFrame(data=mvs_dates)
mvs_dates['est_greve'] = np.ones(mvs_dates.shape[0])

# %%
dt_pos_cor_inc['JOUR'] = pd.to_datetime(dt_pos_cor_inc['JOUR'])
df_merged = pd.merge(dt_pos_cor_inc,mvs_dates, left_on='JOUR',right_on='date',how='left')
df_merged = df_merged.drop(columns=['date'])
df_merged["est_greve"].fillna(0, inplace = True)
df_merged.head()
# Out:
#         JOUR                 LIBELLE_ARRET  NB_VALD        lon       lat  \
# 0 2015-01-01                      ABBESSES      750  48.884505  2.338365
# 1 2015-01-01                         ABLON      118        NaN       NaN
# 2 2015-01-01         ACHERES-GRAND-CORMIER       18  48.955388  2.092457
# 3 2015-01-01                 ACHERES-VILLE      482  48.970248  2.077672
# 4 2015-01-01  AEROPORT CHARLES DE GAULLE 1     1257  49.010400  2.561357
#
#            res_com          mode_  principal  nb_metro  nb_rer line  \
# 0              M12          Metro        0.0       1.0     0.0   12
# 1            RER C            RER        0.0       0.0     1.0  NaN
# 2            RER A            RER        0.0       0.0     1.0  NaN
# 3  LIGNE L / RER A    Train / RER        0.0       0.0     1.0  NaN
# 4   RER B / CDGVAL  RER / Navette        0.0       0.0     1.0  NaN
#
#   Segment DRG  Nbre plateformes duree type_inc  num_inc  est_greve
# 0         NaN               NaN   NaT      NaN      NaN        0.0
# 1           b               1.0   NaT      NaN      NaN        0.0
# 2         NaN               NaN   NaT      NaN      NaN        0.0
# 3         NaN               NaN   NaT      NaN      NaN        0.0
# 4         NaN               NaN   NaT      NaN      NaN        0.0

# %% [markdown]
# ###  8 . Stations timetable Data / Horaires des gares

# %%
horaires_gares = pd.read_csv('data/horaires-des-gares.csv',delimiter = ';')
horaires_gares = horaires_gares[['Gare','Jour de la semaine','Horaire en jour normal', 'Horaire en jour férié']]
horaires_gares['Gare']  = horaires_gares['Gare'].apply(lambda x : x.upper())
horaires_gares.head()
# Out:
#               Gare Jour de la semaine Horaire en jour normal  \
# 0  BANYULS-SUR-MER           Mercredi            14:30-18:00
# 1  BANYULS-SUR-MER              Jeudi            09:15-13:00
# 2  ARGELÈS-SUR-MER           Vendredi            05:35-22:10
# 3       RIVESALTES              Lundi            05:30-22:35
# 4       RIVESALTES              Mardi            05:30-22:35
#
#   Horaire en jour férié
# 0                   NaN
# 1                   NaN
# 2           05:35-22:10
# 3           05:30-22:35
# 4           05:30-22:35

# %%
df_merged['Jour de la semaine'] = df_merged['JOUR'].apply(lambda x : calendar.day_name [x.date().weekday()])
jour_eng = ['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday']
jour_fr = ['Lundi','Mardi','Mercredi','Jeudi','Vendredi','Samedi','Dimanche']
horaires_gares['Jour de la semaine'] = horaires_gares['Jour de la semaine'].apply(lambda x : jour_eng[jour_fr.index(x)])

# %%
df_merged = pd.merge(df_merged,horaires_gares , left_on = ['LIBELLE_ARRET','Jour de la semaine'],right_on = ['Gare','Jour de la semaine'],how = 'left')
df_merged = df_merged.drop(['Gare'],axis=1)
df_merged.head()
# Out:
#         JOUR                 LIBELLE_ARRET  NB_VALD        lon       lat  \
# 0 2015-01-01                      ABBESSES      750  48.884505  2.338365
# 1 2015-01-01                         ABLON      118        NaN       NaN
# 2 2015-01-01         ACHERES-GRAND-CORMIER       18  48.955388  2.092457
# 3 2015-01-01                 ACHERES-VILLE      482  48.970248  2.077672
# 4 2015-01-01  AEROPORT CHARLES DE GAULLE 1     1257  49.010400  2.561357
#
#            res_com          mode_  principal  nb_metro  nb_rer line  \
# 0              M12          Metro        0.0       1.0     0.0   12
# 1            RER C            RER        0.0       0.0     1.0  NaN
# 2            RER A            RER        0.0       0.0     1.0  NaN
# 3  LIGNE L / RER A    Train / RER        0.0       0.0     1.0  NaN
# 4   RER B / CDGVAL  RER / Navette        0.0       0.0     1.0  NaN
#
#   Segment DRG  Nbre plateformes duree type_inc  num_inc  est_greve  \
# 0         NaN               NaN   NaT      NaN      NaN        0.0
# 1           b               1.0   NaT      NaN      NaN        0.0
# 2         NaN               NaN   NaT      NaN      NaN        0.0
# 3         NaN               NaN   NaT      NaN      NaN        0.0
# 4         NaN               NaN   NaT      NaN      NaN        0.0
#
#   Jour de la semaine Horaire en jour normal Horaire en jour férié
# 0           Thursday                    NaN                   NaN
# 1           Thursday                    NaN                   NaN
# 2           Thursday                    NaN                   NaN
# 3           Thursday                    NaN                   NaN
# 4           Thursday                    NaN                   NaN

# %% [markdown]
# ### 9 . Day off Data ( Jours féries )

# %%
data_ferie = pd.read_csv("./data/jours-feries.csv")
data_ferie.head()
# Out:
#          date  est_jour_ferie nom_jour_ferie
# 0  1950-01-01            True   Jour de l'an
# 1  1950-01-02           False            NaN
# 2  1950-01-03           False            NaN
# 3  1950-01-04           False            NaN
# 4  1950-01-05           False            NaN

# %%
# Let's convert dates into datetime type
data_ferie['date'] = pd.to_datetime(data_ferie['date'],format="%Y/%m/%d")
# Let's keep only dates between 2015-01-01 and 2019-06-30
data_ferie=data_ferie[data_ferie['date'].isin(pd.date_range(start='20150101', end='20190630'))]
# Let's replace NaN values by "jour non ferie"
data_ferie["nom_jour_ferie"].fillna("Jour non ferie", inplace = True)

# %%
data_ferie.columns = ['date','est_jour_ferie','type_jour']
data_ferie.head()
# Out:
#             date  est_jour_ferie       type_jour
# 23741 2015-01-01            True    Jour de l'an
# 23742 2015-01-02           False  Jour non ferie
# 23743 2015-01-03           False  Jour non ferie
# 23744 2015-01-04           False  Jour non ferie
# 23745 2015-01-05           False  Jour non ferie

# %%
# Encoder la colonne 'est_jour_ferié' : True => 1 et False => 0
data_ferie.est_jour_ferie = data_ferie.est_jour_ferie.astype(int)
data_ferie.head()
# Out:
#             date  est_jour_ferie       type_jour
# 23741 2015-01-01               1    Jour de l'an
# 23742 2015-01-02               0  Jour non ferie
# 23743 2015-01-03               0  Jour non ferie
# 23744 2015-01-04               0  Jour non ferie
# 23745 2015-01-05               0  Jour non ferie

# %% [markdown]
# ### 10 .  Feature Engineering:  Week-End Days

# %%
data_ferie['est_weekend'] = data_ferie['date'].map(lambda x : 1 if x.weekday() >= 5 else 0 )
data_ferie.head()
# Out:
#             date  est_jour_ferie       type_jour  est_weekend
# 23741 2015-01-01               1    Jour de l'an            0
# 23742 2015-01-02               0  Jour non ferie            0
# 23743 2015-01-03               0  Jour non ferie            1
# 23744 2015-01-04               0  Jour non ferie            1
# 23745 2015-01-05               0  Jour non ferie            0

# %%
#Ajouter le type "Weekend" pour la colonne "type_jour"
mask = (data_ferie['est_weekend'] == 1) 
data_ferie['type_jour'][mask] = "Weekend"
data_ferie.head()
# Out:
#             date  est_jour_ferie       type_jour  est_weekend
# 23741 2015-01-01               1    Jour de l'an            0
# 23742 2015-01-02               0  Jour non ferie            0
# 23743 2015-01-03               0         Weekend            1
# 23744 2015-01-04               0         Weekend            1
# 23745 2015-01-05               0  Jour non ferie            0

# %%
data_ferie.drop('est_weekend',axis=1,inplace=True)
data_ferie.head()
# Out:
#             date  est_jour_ferie       type_jour
# 23741 2015-01-01               1    Jour de l'an
# 23742 2015-01-02               0  Jour non ferie
# 23743 2015-01-03               0         Weekend
# 23744 2015-01-04               0         Weekend
# 23745 2015-01-05               0  Jour non ferie

# %%
df_merged = pd.merge(df_merged, data_ferie, left_on='JOUR',right_on='date',how='left')
df_merged.drop('date',axis=1,inplace=True)
df_merged.head()
# Out:
#         JOUR                 LIBELLE_ARRET  NB_VALD        lon       lat  \
# 0 2015-01-01                      ABBESSES      750  48.884505  2.338365
# 1 2015-01-01                         ABLON      118        NaN       NaN
# 2 2015-01-01         ACHERES-GRAND-CORMIER       18  48.955388  2.092457
# 3 2015-01-01                 ACHERES-VILLE      482  48.970248  2.077672
# 4 2015-01-01  AEROPORT CHARLES DE GAULLE 1     1257  49.010400  2.561357
#
#            res_com          mode_  principal  nb_metro  nb_rer  ...  \
# 0              M12          Metro        0.0       1.0     0.0  ...
# 1            RER C            RER        0.0       0.0     1.0  ...
# 2            RER A            RER        0.0       0.0     1.0  ...
# 3  LIGNE L / RER A    Train / RER        0.0       0.0     1.0  ...
# 4   RER B / CDGVAL  RER / Navette        0.0       0.0     1.0  ...
#
#   Nbre plateformes duree  type_inc num_inc est_greve  Jour de la semaine  \
# 0              NaN   NaT       NaN     NaN       0.0            Thursday
# 1              1.0   NaT       NaN     NaN       0.0            Thursday
# 2              NaN   NaT       NaN     NaN       0.0            Thursday
# 3              NaN   NaT       NaN     NaN       0.0            Thursday
# 4              NaN   NaT       NaN     NaN       0.0            Thursday
#
#    Horaire en jour normal Horaire en jour férié est_jour_ferie     type_jour
# 0                     NaN                   NaN              1  Jour de l'an
# 1                     NaN                   NaN              1  Jour de l'an
# 2                     NaN                   NaN              1  Jour de l'an
# 3                     NaN                   NaN              1  Jour de l'an
# 4                     NaN                   NaN              1  Jour de l'an
#
# [5 rows x 22 columns]

# %%
X_train,X_test = train_test_split(df_merged, test_size=0.33, random_state=42)

# %%
X_train.head()
# Out:
#               JOUR         LIBELLE_ARRET  NB_VALD        lon       lat  \
# 259473  2015-12-01        LES GRESILLONS     3008        NaN       NaN
# 255030  2015-11-25          ERMONT-HALTE      544        NaN       NaN
# 490696  2016-09-19  COURCELLE-SUR-YVETTE     1091  48.700934  2.099045
# 1047961 2019-02-23           RAMBOUILLET     2718  48.844479  2.381176
# 1050591 2019-02-27         FR. POPULAIRE     7627        NaN       NaN
#
#          res_com  mode_  principal  nb_metro  nb_rer  ... Nbre plateformes  \
# 259473     RER C    RER        0.0       0.0     1.0  ...              NaN
# 255030   LIGNE H  Train        0.0       0.0     0.0  ...              NaN
# 490696     RER B    RER        0.0       0.0     1.0  ...              NaN
# 1047961  LIGNE N  Train        1.0       0.0     0.0  ...              1.0
# 1050591      NaN    NaN        NaN       NaN     NaN  ...              NaN
#
#         duree  type_inc num_inc est_greve  Jour de la semaine  \
# 259473    NaT       NaN     NaN       0.0             Tuesday
# 255030    NaT       NaN     NaN       0.0           Wednesday
# 490696    NaT       NaN     NaN       0.0              Monday
# 1047961   NaT       NaN     NaN       0.0            Saturday
# 1050591   NaT       NaN     NaN       0.0           Wednesday
#
#          Horaire en jour normal Horaire en jour férié est_jour_ferie  \
# 259473                      NaN                   NaN              0
# 255030                      NaN                   NaN              0
# 490696                      NaN                   NaN              0
# 1047961                     NaN                   NaN              0
# 1050591                     NaN                   NaN              0
#
#               type_jour
# 259473   Jour non ferie
# 255030   Jour non ferie
# 490696   Jour non ferie
# 1047961         Weekend
# 1050591  Jour non ferie
#
# [5 rows x 22 columns]

# %% [markdown]
# ## 11. Save Data

# %%
X_train.to_csv('./data/data challenge/data_challenge_TRAIN.csv',index=False)
X_test.to_csv('./data/data challenge/data_challenge_TEST.csv',index=False)

# %% [markdown]
# This final data will be used in the notebook : DataCamp Challenge
